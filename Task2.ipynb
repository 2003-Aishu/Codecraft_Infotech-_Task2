# %% [markdown]
# 🔹✅ "To perform data cleaning and exploratory data analysis (EDA) on the Titanic dataset. This involves handling missing values, correcting data types, and exploring patterns and relationships between features (e.g., Age, Sex, Pclass) and the target variable Survived"

# %% [markdown]
# ✅ Step 1: Load Required Libraries & Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Load the dataset
df = pd.read_csv("C:/Users/Aishwarya/Downloads/train.csv")

# %% [markdown]
# ✅ Step 2: Data Cleaning (already done)

# %%
# Fill missing Age with median
df['Age'] = df['Age'].fillna(df['Age'].median())

# Fill missing Embarked with mode
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# ✅ Step 3: Basic Data Exploration

# %%
# Basic info
df.info()

# Summary stats
df.describe()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %% [markdown]
# ✅ Step 4: Univariate Analysis (One Variable at a Time)

# %% [markdown]
# 🔹 Countplot - Survival

# %%
sns.countplot(x='Survived', data=df)
plt.title("Survival Count (0 = No, 1 = Yes)")
plt.show()

# %% [markdown]
# 🔹 Distribution - Age

# %%
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# 🔹 Countplot - Pclass

# %%
sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class Count")
plt.show()

# %% [markdown]
# ✅ Step 5: Bivariate Analysis (Compare Two Variables)

# %% [markdown]
# 🔸 Survival by Sex

# %%
sns.countplot(x='Survived', hue='Sex', data=df)
plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# 🔸 Survival by Pclass

# %%
sns.countplot(x='Survived', hue='Pclass', data=df)
plt.title("Survival by Passenger Class")
plt.show()

# %% [markdown]
# 🔸 Age vs. Survival

# %%
sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age vs. Survival")
plt.show()

# %% [markdown]
# ✅ Step 6: Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ✅ Step 7: Key Observations After visualizing, summarize insights:
#
# 🔸Women survived more than men.
#
# 🔸Higher class (Pclass 1) had better survival rates.
#
# 🔸Children had slightly higher survival chances.
